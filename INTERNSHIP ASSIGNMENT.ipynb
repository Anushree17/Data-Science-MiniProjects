# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_excel(r"C:\Users\jhaan\Desktop\RGI_Network_List_3527\task.xls")
df
# Out:
#       Sr.No. Provider Code                                      Hospital_Name  \
# 0          1     HGIX00001                          Adya Eye And Ent Hospital
# 1          2     HGIX00003                            Adarsh Hospital Pvt Ltd
# 2          3     HGIX00004  Amrut Multi Speciality Hospital (Parikh Multi ...
# 3          4     HGIX00008                 Apollo Hospitals International Ltd
# 4          5     HGIX00009                            Arpan Surgical Hospital
# ...      ...           ...                                                ...
# 4406    4407     HGIX04948  Navodaya Hospital for Women & Children ( A Uni...
# 4407    4408     HGIX04953                      Sateesh Gastro & Liver Centre
# 4408    4409     HGIX04954  Andhra Hospitals Machilipatnam ( A Unit of Vis...
# 4409    4410     HGIX04955                                     S.A.I Hospital
# 4410    4411     HGIX04956                     Apollo Gleneagles Heart Centre
#
# ...

# %%
df.columns
# Out:
# Index(['Sr.No.', 'Provider Code', 'Hospital_Name', 'Address', 'State',
#        'District', 'City', 'Area', 'Pin_Code', 'Pan_Card No.',
#        'Account_Number', 'Vendor_Code', 'Key'],
#       dtype='object')

# %%
df1=df.head(100)
df1
# Out:
#     Sr.No. Provider Code                                      Hospital_Name  \
# 0        1     HGIX00001                          Adya Eye And Ent Hospital
# 1        2     HGIX00003                            Adarsh Hospital Pvt Ltd
# 2        3     HGIX00004  Amrut Multi Speciality Hospital (Parikh Multi ...
# 3        4     HGIX00008                 Apollo Hospitals International Ltd
# 4        5     HGIX00009                            Arpan Surgical Hospital
# ..     ...           ...                                                ...
# 95      96     HGIX00131                 Jethwa Eye Hospital & Laser Centre
# 96      97     HGIX00132     Jay Polyclinic Maternity Surgical Nursing Home
# 97      98     HGIX00133                               Agrawal Eye Hospital
# 98      99     HGIX00134  Orange City Hospital & Research Institute (A U...
# 99     100     HGIX00136      Hope Mulitspiality Hospital & Research Centre
#
# ...

# %%
df1.isnull().sum()
# Out:
# Sr.No.            0
# Provider Code     0
# Hospital_Name     0
# Address           0
# State             0
# District          0
# City              0
# Area              0
# Pin_Code          0
# Pan_Card No.      0
# Account_Number    0
# Vendor_Code       0
# Key               0
# dtype: int64

# %%
df.to_excel(r"C:\Users\jhaan\Desktop\RGI_Network_List_3527\task1.xls")
